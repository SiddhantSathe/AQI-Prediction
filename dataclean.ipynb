# %%
import pandas as pd

df = pd.read_csv("dataset\AQI.csv")
df.columns
# Out:
# Index(['country', 'state', 'city', 'station', 'last_update', 'latitude',
#        'longitude', 'pollutant_id', 'pollutant_min', 'pollutant_max',
#        'pollutant_avg'],
#       dtype='object')

# %%
upd = df.dropna()
upd
# Out:
#      country           state               city  \
# 0      India  Andhra_Pradesh          Amaravati
# 1      India  Andhra_Pradesh          Anantapur
# 4      India  Andhra_Pradesh             Kadapa
# 5      India  Andhra_Pradesh  Rajamahendravaram
# 6      India  Andhra_Pradesh           Tirupati
# ...      ...             ...                ...
# 3315   India     West_Bengal            Kolkata
# 3316   India     West_Bengal            Kolkata
# 3317   India     West_Bengal            Kolkata
# 3318   India     West_Bengal           Siliguri
# 3319   India     West_Bengal           Siliguri
#
#                                              station          last_update  \
# 0                     Secretariat, Amaravati - APPCB  26-06-2024 21:00:00
# 1                       Gulzarpet, Anantapur - APPCB  26-06-2024 21:00:00
# 4                    Yerramukkapalli, Kadapa - APPCB  26-06-2024 21:00:00
# 5     Anand Kala Kshetram, Rajamahendravaram - APPCB  26-06-2024 21:00:00
# ...

# %%
df["pollutant_id"].values
air_pollutants = df["pollutant_id"].unique()
air_pollutants
nh3 = df[df["pollutant_id"] == "NH3"][['country', 'state', 'city', 'station', 'last_update', 'latitude',
       'longitude', 'pollutant_id', 'pollutant_min', 'pollutant_max',
       'pollutant_avg']]
no2 = df[df["pollutant_id"] == "NO2"][['country', 'state', 'city', 'station', 'last_update', 'latitude',
       'longitude', 'pollutant_id', 'pollutant_min', 'pollutant_max',
       'pollutant_avg']]
so2 = df[df["pollutant_id"] == "SO2"][['country', 'state', 'city', 'station', 'last_update', 'latitude',
       'longitude', 'pollutant_id', 'pollutant_min', 'pollutant_max',
       'pollutant_avg']]
co = df[df["pollutant_id"] == "CO"][['country', 'state', 'city', 'station', 'last_update', 'latitude',
       'longitude', 'pollutant_id', 'pollutant_min', 'pollutant_max',
       'pollutant_avg']]
o3 = df[df["pollutant_id"] == "O3"][['country', 'state', 'city', 'station', 'last_update', 'latitude',
       'longitude', 'pollutant_id', 'pollutant_min', 'pollutant_max',
       'pollutant_avg']]
pm10 = df[df["pollutant_id"] == "PM10"][['country', 'state', 'city', 'station', 'last_update', 'latitude',
       'longitude', 'pollutant_id', 'pollutant_min', 'pollutant_max',
       'pollutant_avg']]
pm25 = df[df["pollutant_id"] == "PM2.5"][['country', 'state', 'city', 'station', 'last_update', 'latitude',
       'longitude', 'pollutant_id', 'pollutant_min', 'pollutant_max',
       'pollutant_avg']]
nh3
# Out:
#      country           state        city  \
# 0      India  Andhra_Pradesh   Amaravati
# 14     India  Andhra_Pradesh  Vijayawada
# 18     India  Andhra_Pradesh  Vijayawada
# 23     India           Assam    Guwahati
# 36     India           Bihar      Araria
# ...      ...             ...         ...
# 3306   India     West_Bengal     Kolkata
# 3308   India     West_Bengal     Kolkata
# 3311   India     West_Bengal     Kolkata
# 3315   India     West_Bengal     Kolkata
# 3318   India     West_Bengal    Siliguri
#
#                                     station          last_update   latitude  \
# 0            Secretariat, Amaravati - APPCB  26-06-2024 21:00:00  16.515083
# 14    Rajiv Gandhi Park, Vijayawada - APPCB  26-06-2024 21:00:00  16.509717
# 18          Rajiv Nagar, Vijayawada - APPCB  26-06-2024 21:00:00  16.554731
# 23                    IITG, Guwahati - PCBA  26-06-2024 21:00:00  26.202864
# 36          Kharahiya Basti, Araria - BSPCB  26-06-2024 21:00:00  26.146529
# ...

# %%
import aqi

# Convert PM2.5 concentration to IAQI using EPA algorithm
pm25_iaqi = aqi.to_iaqi(aqi.POLLUTANT_PM25, '12', algo=aqi.ALGO_EPA)
print(f"PM2.5 IAQI: {pm25_iaqi}")

# Get overall AQI from multiple pollutant concentrations (default algorithm: EPA)
aqi_values = aqi.to_aqi([
    (aqi.POLLUTANT_PM25, '12'),
    (aqi.POLLUTANT_PM10, '24'),
    (aqi.POLLUTANT_O3_8H, '0.087')
])
print(f"Overall AQI: {aqi_values}")
# Out:
# PM2.5 IAQI: 50
# Overall AQI: 129

# %%
# api
import requests
import json

url = "https://api.data.gov.in/resource/3b01bcb8-0b14-4abf-b6f2-c1bfd384ba69?api-key=579b464db66ec23bdd0000018c3f8695dbda465b7dae2b3252d29f09&format=json"

response = requests.get(url)
data = response.json()

data = json.dumps(data, indent=4)
print(data)
# Out:
# {
#     "created": 1697709635,
#     "updated": 1703143837,
#     "created_date": "2023-10-19T15:30:35Z",
#     "updated_date": "2023-12-21T13:00:37Z",
#     "active": 1,
#     "index_name": "3b01bcb8-0b14-4abf-b6f2-c1bfd384ba69",
#     "message": "Resource lists",
#     "version": "2.2.0",
#     "status": "ok",
#     "total": 3261,
#     "count": 10,
#     "limit": "10",
#     "offset": "0",
#     "field": [
#         "country",
#         "state",
#         "city",
#         "station",
#         "last_update",
#         "latitude",
#         "longitude",
#         "pollutant_id",
#         "pollutant_min",
#         "pollutant_max",
#         "pollutant_avg"
#     ],
#     "records": [
#         {
#             "country": "India",
#             "state": "Andhra_Pradesh",
#             "city": "Amaravati",
#             "station": "Secretariat, Amaravati - APPCB",
#             "last_update": "28-06-2024 14:00:00",
#             "latitude": "16.5150833",
# ...

# %%
import requests
import json
# from mindsdb import Model, Predictor

# %%
API_KEY = "579b464db66ec23bdd0000018c3f8695dbda465b7dae2b3252d29f09"  # Replace with your API key
API_URL = "https://api.data.gov.in/resource/3b01bcb8-0b14-4abf-b6f2-c1bfd384ba69?api-key=579b464db66ec23bdd0000018c3f8695dbda465b7dae2b3252d29f09&format=json"  # Replace with your API endpoint
# LOCATION_ID = "1234"  # Replace with your location ID (if applicable)

# %%
def get_air_quality_data():
  """
  Fetches air quality data from the API and returns a dictionary.
  """
  url = f"{API_URL}"
  headers = {"Authorization": f"Bearer {API_KEY}"}
  response = requests.get(url, headers=headers)
  data = response.json()  # Parse the API response (assuming JSON format)
  return data

# %% [markdown]
# <h3>MindsDB connection </h3>

# %%
from mindsdb_sdk import SDK

# Connect to MindsDB running in Docker
sdk = SDK('http://localhost:47334')

# List all predictors
predictors = sdk.predictors.list()
for predictor in predictors:
    print(predictor.name)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 from mindsdb_sdk import SDK
#       3 # Connect to MindsDB running in Docker
#       4 sdk = SDK('http://localhost:47334')
#
# ModuleNotFoundError: No module named 'mindsdb_sdk'

# %% [markdown]
# <h3>API key for real time aqi</h3>
# 579b464db66ec23bdd0000018c3f8695dbda465b7dae2b3252d29f09
